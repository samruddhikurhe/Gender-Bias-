# %%
import pandas as pd
import random

# %%
# Load the male similarity Excel file
male_similarity_df = pd.read_excel("male_similarity.xlsx")

# Preview the dataframe
male_similarity_df.head()
# Out:
#                                              Tweet 1  \
# 0  Also - the jokes. The jokes. \u2018If I now sh...
# 1  Also - the jokes. The jokes. \u2018If I now sh...
# 2  Also - the jokes. The jokes. \u2018If I now sh...
# 3  Also - the jokes. The jokes. \u2018If I now sh...
# 4  Also - the jokes. The jokes. \u2018If I now sh...
#
#                                              Tweet 2  Similarity Score
# 0  Still,better than my neighbour or'Stalker' as ...          0.286326
# 1  Thanks @BDUTT for being the rare voice in the ...          0.439234
# 2  I have been asking media houses to debate this...          0.344894
# 3  @HBO it's also not ok to abuse, threaten &amp;...          0.443727
# 4  @Channel4 This looks great but Sean Penn\u2019...          0.427945

# %%
# Ensure enough data
assert len(male_similarity_df) >= 50, "Not enough pairs in the file!"

# Randomly sample 50 pairs
male_50_pairs = male_similarity_df.sample(n=50, random_state=42).reset_index(drop=True)

# Show sample
male_50_pairs.head()
# Out:
#                                              Tweet 1  \
# 0  #MeToo I was afraid. Now I\u2019m not. He took...
# 1  @HBO it's also not ok to abuse, threaten &amp;...
# 2  This happened post #MeToo &amp; Sarah Scott di...
# 3  Pakistani actor Salman Saqib Sheikh, better kn...
# 4  #MeToo I was afraid. Now I\u2019m not. He took...
#
#                                              Tweet 2  Similarity Score
# 0  It\u2019s hard to believe Brett Kavanaugh\u200...          0.272462
# 1  Who decides what violence should not count as ...          0.440153
# 2  Excellent news. Should have happened right awa...          0.398999
# 3  #Tekashi69's team are now taking down all comm...          0.430075
# 4  IMPORTANT : My DMs are open. Let's hear #HimTo...          0.447153

# %%
# Save to Excel
male_50_pairs.to_excel("male_50_random_pairs.xlsx", index=False)
print("💾 File saved as 'male_50_random_pairs.xlsx'")
# Out:
# 💾 File saved as 'male_50_random_pairs.xlsx'

# %%
female_similarity_df = pd.read_excel("female_similarity.xlsx")

# Preview the dataframe
female_similarity_df.head()
# Out:
#                                              Tweet 1  \
# 0  #MeToo #MeTooIndia #MeTooControversy #MeToo4Pu...
# 1  #MeToo #MeTooIndia #MeTooControversy #MeToo4Pu...
# 2  #MeToo #MeTooIndia #MeTooControversy #MeToo4Pu...
# 3  #MeToo #MeTooIndia #MeTooControversy #MeToo4Pu...
# 4  #MeToo #MeTooIndia #MeTooControversy #MeToo4Pu...
#
#                                              Tweet 2  Similarity Score
# 0  In the past few days, several incidents of fau...          0.657582
# 1  \"The woman who does not require validation fr...          0.377890
# 2  Hey @JimmyKimmelLive,  strangely you guys forg...          0.404276
# 3  First hand account of a survivor from @TeachFo...          0.426601
# 4  @DeShobhaa No Hindu Vrat is compulsory , gener...          0.315621

# %%
# Ensure enough data
assert len(female_similarity_df) >= 50, "Not enough pairs in the file!"

# Randomly sample 50 pairs
female_50_pairs = female_similarity_df.sample(n=50, random_state=42).reset_index(drop=True)

# Show sample
female_50_pairs.head()
# Out:
#                                              Tweet 1  \
# 0  When woman file #FakeCases Indian police.. #Fa...
# 1  Public places must be made safe for women and ...
# 2  As awakened and socially courageous group of p...
# 3  @wolfblitzer @Chloe_Melas @CNNSitRoom In your ...
# 4  #GeoffreyRush is #innocent. #ErynJeanNorvill i...
#
#                                              Tweet 2  Similarity Score
# 0  @GabbbarSingh Now she will play the game of #M...          0.340140
# 1  The only national leader &amp; politician to h...          0.448584
# 2  \u2018I knew if a woman could be President, I ...          0.326949
# 3  No #MeToo for Bengaluru\u2019s Garment Workers...          0.223366
# 4  @kylegriffin1 Make no mistake. This is not onl...          0.337168

# %%
# Save to Excel
female_50_pairs.to_excel("female_50_random_pairs.xlsx", index=False)
print("💾 File saved as 'female_50_random_pairs.xlsx'")
# Out:
# 💾 File saved as 'female_50_random_pairs.xlsx'

# %%
# Load the male similarity Excel file
both_similarity_df = pd.read_excel("both_similarity.xlsx")

# Preview the dataframe
both_similarity_df.head()
# Out:
#                                              Tweet 1  \
# 0  Watching #IranUnveiled on ITV. The kind of opp...
# 1  Watching #IranUnveiled on ITV. The kind of opp...
# 2  Watching #IranUnveiled on ITV. The kind of opp...
# 3  Watching #IranUnveiled on ITV. The kind of opp...
# 4  Watching #IranUnveiled on ITV. The kind of opp...
#
#                                              Tweet 2  Similarity Score
# 0  @MuralikrishnaE1 @ssingapuri @RV9933 @swetasam...          0.241087
# 1  I was going to be a Hillary Supporter, Vegan, ...          0.402376
# 2  Breaking down gender stereotypes allows boys, ...          0.322412
# 3  \u2757\ufe0f#MeToo  A journalist has been work...          0.373701
# 4  @RogueNASA Except they actually know Kavanaugh...          0.396230

# %%
# Ensure enough data
assert len(both_similarity_df) >= 50, "Not enough pairs in the file!"

# Randomly sample 50 pairs
both_50_pairs = both_similarity_df.sample(n=50, random_state=42).reset_index(drop=True)

# Show sample
both_50_pairs.head()
# Out:
#                                              Tweet 1  \
# 0  After Time's Up and #MeToo, women in entertain...
# 1  #MeToo Founder Tarana Burke Breaks Down Why Bi...
# 2  Embracing ambiguities n confusions abt #metoo ...
# 3  Well done #hamont. Tonight's event with #metoo...
# 4  Proud of Latinas Speaking up!  @MonicaRamirezD...
#
#                                              Tweet 2  Similarity Score
# 0  Embracing ambiguities n confusions abt #metoo ...          0.500329
# 1  This is horrifying, sexist, and unacceptable. ...          0.183286
# 2  Founder Director, St. Stephen's School, Chandi...          0.213904
# 3  More than 1/3 of women have been harassed at s...          0.236601
# 4  @ZellnerLaw @metacritic @lifeafterten @EFMoria...          0.336776

# %%
# Save to Excel
both_50_pairs.to_excel("both_50_random_pairs.xlsx", index=False)
print("💾 File saved as 'both_50_random_pairs.xlsx'")
# Out:
# 💾 File saved as 'both_50_random_pairs.xlsx'
